# %%
print("PRAISE THE LORD ALMIGHTY FATHER Thank You JESUS Praise You JESUS Forever May the HOLY SPIRIT Guide Us MOTHER MARY PRAY For Us SAINT JOSEPH, PRAY For Us SAINT ANTHONY PRAY For Us GOD BLESS !!! ⛪✝🧡✝⛪")
# Out:
# PRAISE THE LORD ALMIGHTY FATHER Thank You JESUS Praise You JESUS Forever May the HOLY SPIRIT Guide Us MOTHER MARY PRAY For Us SAINT JOSEPH, PRAY For Us SAINT ANTHONY PRAY For Us GOD BLESS !!! ⛪✝🧡✝⛪

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.set_option('display.max_columns', None)

# %%
df_matches = pd.read_csv('2022_to_2023_all_matches.csv')
df_matches
# Out:
#        Unnamed: 0            year  over_start_bowler_balls_bowled  \
# 0               0  ['2015-11-26']                               0
# 1               1  ['2015-11-26']                               0
# 2               2  ['2015-11-26']                               6
# 3               3  ['2015-11-26']                               7
# 4               4  ['2015-11-26']                              12
# ...           ...             ...                             ...
# 19105       19105  ['2018-04-03']                               6
# 19106       19106  ['2018-04-03']                              12
# 19107       19107  ['2018-04-03']                              12
# 19108       19108  ['2018-04-03']                              18
# 19109       19109  ['2018-04-03']                              12
#
#        over_start_bowler_wickets_taken  over_start_bowler_runs_given  \
# 0                                    0                             0
# ...

# %%
df_matches.columns
# Out:
# Index(['Unnamed: 0', 'year', 'over_start_bowler_balls_bowled',
#        'over_start_bowler_wickets_taken', 'over_start_bowler_runs_given',
#        'over_start_batsman_on_strike_fours',
#        'over_start_batsman_on_strike_sixers',
#        'over_start_batsman_off_strike_balls_faced',
#        'over_start_batsman_on_strike_balls_faced',
#        'over_start_batsman_offstrike_runs', 'over_start_batsman_onstrike_runs',
#        'innings', 'match_num', 'country', 'target', 'req_run_rate',
#        'over_start_run_rate', 'over_start_total_score',
#        'over_start_total_wickets_fallen', 'over', 'Bowler', 'batter_onStrike',
#        'batter_offstrike', 'wickets_fallen', 'sixers', 'fours', 'total_runs',
#        'bat_on_str_Ave', 'bat_on_str_SR', 'bat_on_str_100', 'bat_on_str_50',
#        'bat_on_str_0', 'bat_on_str_4s', 'bat_on_str_6s', 'bat_on_str_Mat',
#        'bat_on_str_Inns', 'bat_on_str_NO', 'bat_on_str_Runs', 'bat_on_str_HS',
# ...

# %%
#Engineer the Run Rate according to the following rules 
def getRequiredRunRate_first_innings(over , wickets):
  if over < 6:
    if wickets < 1:
      return 10
    elif wickets>=1 and wickets<4:
      return  8
    else:
      6
  elif over >= 6 and over<15:
    if wickets < 1:
      return 11
    elif wickets>=1 and wickets<4:
      return  9
    elif wickets>=4 and wickets<6:
      return 8
    else:
      return 6  
  elif over >= 15 and over<20:
    if wickets < 1:
      return 15
    elif wickets>=1 and wickets<7:
      return  12
    else :
      return 10
    # code block 3

current_index = 0

while current_index < len(df_matches):
   if(df_matches['innings'][current_index] == 1):
     #print('Addding the First Innings Required Run Rate index is ' ,current_index)
     df_matches['req_run_rate'][current_index] = getRequiredRunRate_first_innings(df_matches['over'][current_index] , df_matches['over_start_total_wickets_fallen'][current_index])
   current_index = current_index + 1
# Out:
# C:\Users\Arul\AppData\Local\Temp\ipykernel_23416\2851207831.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_matches['req_run_rate'][current_index] = getRequiredRunRate_first_innings(df_matches['over'][current_index] , df_matches['over_start_total_wickets_fallen'][current_index])

# %%
df_matches['date'] = df_matches['year'].apply(lambda x: x[1:-1])

# %%
df_matches['date'] = pd.to_datetime(df_matches['date'])

# %%
df_matches.dtypes
# Out:
# Unnamed: 0                                  int64
# year                                       object
# over_start_bowler_balls_bowled              int64
# over_start_bowler_wickets_taken             int64
# over_start_bowler_runs_given                int64
#                                         ...
# bat_off_str_NO                             object
# bat_off_str_Runs                           object
# bat_off_str_HS                             object
# bat_off_str_BF                             object
# date                               datetime64[ns]
# Length: 65, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Iterate over the columns
for column in df_matches.columns:
    # Count the number of null values in the column
    null_count = df_matches[column].isnull().sum()

    # Display the column name and the number of null values
    print(f"Column '{column}' has {null_count} null values.")
# Out:
# Column 'Unnamed: 0' has 0 null values.
# Column 'year' has 0 null values.
# Column 'over_start_bowler_balls_bowled' has 0 null values.
# Column 'over_start_bowler_wickets_taken' has 0 null values.
# Column 'over_start_bowler_runs_given' has 0 null values.
# Column 'over_start_batsman_on_strike_fours' has 0 null values.
# Column 'over_start_batsman_on_strike_sixers' has 0 null values.
# Column 'over_start_batsman_off_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_on_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_offstrike_runs' has 0 null values.
# Column 'over_start_batsman_onstrike_runs' has 0 null values.
# Column 'innings' has 0 null values.
# Column 'match_num' has 0 null values.
# Column 'country' has 0 null values.
# Column 'target' has 0 null values.
# Column 'req_run_rate' has 19 null values.
# Column 'over_start_run_rate' has 0 null values.
# Column 'over_start_total_score' has 0 null values.
# ...

# %%
## Replacing Null Values with Null

object_columns = ['wickets_fallen', 'sixers', 'fours', 'total_runs',
       'bat_on_str_Ave', 'bat_on_str_SR', 'bat_on_str_100', 'bat_on_str_50',
       'bat_on_str_0', 'bat_on_str_4s', 'bat_on_str_6s', 'bat_on_str_Mat',
       'bat_on_str_Inns', 'bat_on_str_NO', 'bat_on_str_Runs', 'bat_on_str_HS',
       'bat_on_str_BF', 'bowler_Mat', 'bowler_Inns', 'bowler_Overs',
       'bowler_Mdns', 'bowler_Runs', 'bowler_Wkts', 'bowler_Ave',
       'bowler_Econ', 'bowler_SR', 'bowler_4w', 'bowler_5w', 'bat_off_str_Ave',
       'bat_off_str_SR', 'bat_off_str_100', 'bat_off_str_50', 'bat_off_str_0',
       'bat_off_str_4s', 'bat_off_str_6s', 'bat_off_str_Mat',
       'bat_off_str_Inns', 'bat_off_str_NO', 'bat_off_str_Runs',
       'bat_off_str_HS', 'bat_off_str_BF']


for col in object_columns :
    df_matches[col].replace({'-': np.NaN , '':np.NaN , 'nan':np.NaN},inplace=True)

# %%
#Remove the star value in Batsman High Score

current_index = 0

while current_index < len(df_matches):
   try:
    df_matches['bat_off_str_HS'][current_index] = df_matches['bat_off_str_HS'][current_index].replace("*" , "")
   except:
     print("All good" , current_index)

   try:
    df_matches['bat_on_str_HS'][current_index] = df_matches['bat_on_str_HS'][current_index].replace("*" , "")
   except:
     print("All good" , current_index)
   
   current_index = current_index + 1
# Out:
# C:\Users\Arul\AppData\Local\Temp\ipykernel_23416\1425456917.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_matches['bat_off_str_HS'][current_index] = df_matches['bat_off_str_HS'][current_index].replace("*" , "")
# C:\Users\Arul\AppData\Local\Temp\ipykernel_23416\1425456917.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_matches['bat_on_str_HS'][current_index] = df_matches['bat_on_str_HS'][current_index].replace("*" , "")
# All good 2
# All good 3
# All good 4
# All good 5
# All good 6
# All good 7
# All good 8
# All good 9
# All good 10
# All good 11
# All good 12
# All good 13
# ...

# %%
# Iterate over the columns
for column in df_matches.columns:
    # Count the number of null values in the column
    null_count = df_matches[column].isnull().sum()

    # Display the column name and the number of null values
    print(f"Column '{column}' has {null_count} null values.")
# Out:
# Column 'Unnamed: 0' has 0 null values.
# Column 'year' has 0 null values.
# Column 'over_start_bowler_balls_bowled' has 0 null values.
# Column 'over_start_bowler_wickets_taken' has 0 null values.
# Column 'over_start_bowler_runs_given' has 0 null values.
# Column 'over_start_batsman_on_strike_fours' has 0 null values.
# Column 'over_start_batsman_on_strike_sixers' has 0 null values.
# Column 'over_start_batsman_off_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_on_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_offstrike_runs' has 0 null values.
# Column 'over_start_batsman_onstrike_runs' has 0 null values.
# Column 'innings' has 0 null values.
# Column 'match_num' has 0 null values.
# Column 'country' has 0 null values.
# Column 'target' has 0 null values.
# Column 'req_run_rate' has 19 null values.
# Column 'over_start_run_rate' has 0 null values.
# Column 'over_start_total_score' has 0 null values.
# ...

# %%
df_matches.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0            year  over_start_bowler_balls_bowled  \
# 0               0  ['2015-11-26']                               0
# 1               1  ['2015-11-26']                               0
# 2               2  ['2015-11-26']                               6
# 3               3  ['2015-11-26']                               7
# 4               4  ['2015-11-26']                              12
# ...           ...             ...                             ...
# 19105       19105  ['2018-04-03']                               6
# 19106       19106  ['2018-04-03']                              12
# 19107       19107  ['2018-04-03']                              12
# 19108       19108  ['2018-04-03']                              18
# 19109       19109  ['2018-04-03']                              12
#
#        over_start_bowler_wickets_taken  over_start_bowler_runs_given  \
# 0                                    0                             0
# ...

# %%
df_matches.columns
# Out:
# Index(['Unnamed: 0', 'year', 'over_start_bowler_balls_bowled',
#        'over_start_bowler_wickets_taken', 'over_start_bowler_runs_given',
#        'over_start_batsman_on_strike_fours',
#        'over_start_batsman_on_strike_sixers',
#        'over_start_batsman_off_strike_balls_faced',
#        'over_start_batsman_on_strike_balls_faced',
#        'over_start_batsman_offstrike_runs', 'over_start_batsman_onstrike_runs',
#        'innings', 'match_num', 'country', 'target', 'req_run_rate',
#        'over_start_run_rate', 'over_start_total_score',
#        'over_start_total_wickets_fallen', 'over', 'Bowler', 'batter_onStrike',
#        'batter_offstrike', 'wickets_fallen', 'sixers', 'fours', 'total_runs',
#        'bat_on_str_Ave', 'bat_on_str_SR', 'bat_on_str_100', 'bat_on_str_50',
#        'bat_on_str_0', 'bat_on_str_4s', 'bat_on_str_6s', 'bat_on_str_Mat',
#        'bat_on_str_Inns', 'bat_on_str_NO', 'bat_on_str_Runs', 'bat_on_str_HS',
# ...

# %%
columns_to_convert = [ 'wickets_fallen', 'sixers', 'fours', 'total_runs',
       'bat_on_str_Ave', 'bat_on_str_SR', 'bat_on_str_100', 'bat_on_str_50',
       'bat_on_str_0', 'bat_on_str_4s', 'bat_on_str_6s', 'bat_on_str_Mat',
       'bat_on_str_Inns', 'bat_on_str_NO', 'bat_on_str_Runs', 'bat_on_str_HS',
       'bat_on_str_BF', 'bowler_Mat', 'bowler_Inns', 'bowler_Overs',
       'bowler_Mdns', 'bowler_Runs', 'bowler_Wkts', 'bowler_Ave',
       'bowler_Econ', 'bowler_SR', 'bowler_4w', 'bowler_5w', 'bat_off_str_Ave',
       'bat_off_str_SR', 'bat_off_str_100', 'bat_off_str_50', 'bat_off_str_0',
       'bat_off_str_4s', 'bat_off_str_6s', 'bat_off_str_Mat',
       'bat_off_str_Inns', 'bat_off_str_NO', 'bat_off_str_Runs',
       'bat_off_str_HS', 'bat_off_str_BF',]
df_matches[columns_to_convert] = df_matches[columns_to_convert].astype(float)

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19110 entries, 0 to 19109
# Data columns (total 65 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 19110 non-null  int64
#  1   year                                       19110 non-null  object
#  2   over_start_bowler_balls_bowled             19110 non-null  int64
#  3   over_start_bowler_wickets_taken            19110 non-null  int64
#  4   over_start_bowler_runs_given               19110 non-null  int64
#  5   over_start_batsman_on_strike_fours         19110 non-null  int64
#  6   over_start_batsman_on_strike_sixers        19110 non-null  int64
#  7   over_start_batsman_off_strike_balls_faced  19110 non-null  int64
#  8   over_start_batsman_on_strike_balls_faced   19110 non-null  int64
#  9   over_start_batsman_offstrike_runs          19110 non-null  int64
# ...

# %%
# Iterate over the columns
for column in df_matches.columns:
    # Count the number of null values in the column
    null_count = df_matches[column].isnull().sum()

    # Display the column name and the number of null values
    print(f"Column '{column}' has {null_count} null values.")
# Out:
# Column 'Unnamed: 0' has 0 null values.
# Column 'year' has 0 null values.
# Column 'over_start_bowler_balls_bowled' has 0 null values.
# Column 'over_start_bowler_wickets_taken' has 0 null values.
# Column 'over_start_bowler_runs_given' has 0 null values.
# Column 'over_start_batsman_on_strike_fours' has 0 null values.
# Column 'over_start_batsman_on_strike_sixers' has 0 null values.
# Column 'over_start_batsman_off_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_on_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_offstrike_runs' has 0 null values.
# Column 'over_start_batsman_onstrike_runs' has 0 null values.
# Column 'innings' has 0 null values.
# Column 'match_num' has 0 null values.
# Column 'country' has 0 null values.
# Column 'target' has 0 null values.
# Column 'req_run_rate' has 19 null values.
# Column 'over_start_run_rate' has 0 null values.
# Column 'over_start_total_score' has 0 null values.
# ...

# %%
column_to_fill = 'req_run_rate'
df_matches[column_to_fill] = df_matches[column_to_fill].fillna(10)

# %%
# Iterate over the columns
for column in df_matches.columns:
    # Count the number of null values in the column
    null_count = df_matches[column].isnull().sum()

    # Display the column name and the number of null values
    print(f"Column '{column}' has {null_count} null values.")
# Out:
# Column 'Unnamed: 0' has 0 null values.
# Column 'year' has 0 null values.
# Column 'over_start_bowler_balls_bowled' has 0 null values.
# Column 'over_start_bowler_wickets_taken' has 0 null values.
# Column 'over_start_bowler_runs_given' has 0 null values.
# Column 'over_start_batsman_on_strike_fours' has 0 null values.
# Column 'over_start_batsman_on_strike_sixers' has 0 null values.
# Column 'over_start_batsman_off_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_on_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_offstrike_runs' has 0 null values.
# Column 'over_start_batsman_onstrike_runs' has 0 null values.
# Column 'innings' has 0 null values.
# Column 'match_num' has 0 null values.
# Column 'country' has 0 null values.
# Column 'target' has 0 null values.
# Column 'req_run_rate' has 0 null values.
# Column 'over_start_run_rate' has 0 null values.
# Column 'over_start_total_score' has 0 null values.
# ...

# %%
mean_column_to_fill = ['wickets_fallen', 'sixers', 'fours', 'total_runs',
       'bat_on_str_Ave', 'bat_on_str_SR', 'bat_on_str_100', 'bat_on_str_50',
       'bat_on_str_0', 'bat_on_str_4s', 'bat_on_str_6s', 'bat_on_str_Mat',
       'bat_on_str_Inns', 'bat_on_str_NO', 'bat_on_str_Runs', 'bat_on_str_HS',
       'bat_on_str_BF', 'bowler_Mat', 'bowler_Inns', 'bowler_Overs',
       'bowler_Mdns', 'bowler_Runs', 'bowler_Wkts', 'bowler_Ave',
       'bowler_Econ', 'bowler_SR', 'bowler_4w', 'bowler_5w', 'bat_off_str_Ave',
       'bat_off_str_SR', 'bat_off_str_100', 'bat_off_str_50', 'bat_off_str_0',
       'bat_off_str_4s', 'bat_off_str_6s', 'bat_off_str_Mat',
       'bat_off_str_Inns', 'bat_off_str_NO', 'bat_off_str_Runs',
       'bat_off_str_HS', 'bat_off_str_BF']

# %%
for column in mean_column_to_fill:
    df_matches[column] = df_matches[column].fillna(df_matches[column].mean())

# %%
# Iterate over the columns
for column in df_matches.columns:
    # Count the number of null values in the column
    null_count = df_matches[column].isnull().sum()

    # Display the column name and the number of null values
    print(f"Column '{column}' has {null_count} null values.")
# Out:
# Column 'Unnamed: 0' has 0 null values.
# Column 'year' has 0 null values.
# Column 'over_start_bowler_balls_bowled' has 0 null values.
# Column 'over_start_bowler_wickets_taken' has 0 null values.
# Column 'over_start_bowler_runs_given' has 0 null values.
# Column 'over_start_batsman_on_strike_fours' has 0 null values.
# Column 'over_start_batsman_on_strike_sixers' has 0 null values.
# Column 'over_start_batsman_off_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_on_strike_balls_faced' has 0 null values.
# Column 'over_start_batsman_offstrike_runs' has 0 null values.
# Column 'over_start_batsman_onstrike_runs' has 0 null values.
# Column 'innings' has 0 null values.
# Column 'match_num' has 0 null values.
# Column 'country' has 0 null values.
# Column 'target' has 0 null values.
# Column 'req_run_rate' has 0 null values.
# Column 'over_start_run_rate' has 0 null values.
# Column 'over_start_total_score' has 0 null values.
# ...

# %%
df_matches
# Out:
#        Unnamed: 0            year  over_start_bowler_balls_bowled  \
# 0               0  ['2015-11-26']                               0
# 1               1  ['2015-11-26']                               0
# 2               2  ['2015-11-26']                               6
# 3               3  ['2015-11-26']                               7
# 4               4  ['2015-11-26']                              12
# ...           ...             ...                             ...
# 19105       19105  ['2018-04-03']                               6
# 19106       19106  ['2018-04-03']                              12
# 19107       19107  ['2018-04-03']                              12
# 19108       19108  ['2018-04-03']                              18
# 19109       19109  ['2018-04-03']                              12
#
#        over_start_bowler_wickets_taken  over_start_bowler_runs_given  \
# 0                                    0                             0
# ...

# %%
df_matches.insert(54,"y_is_wicket_fallen", " ")


#Add 1 and 0 if a wicket has fallen in the next over

current_index = 0

while current_index < len(df_matches):
   if df_matches['wickets_fallen'][current_index] > 0:   
      df_matches['y_is_wicket_fallen'][current_index] = 1
   else:
      df_matches['y_is_wicket_fallen'][current_index] = 0
      
   current_index = current_index + 1
# Out:
# C:\Users\Arul\AppData\Local\Temp\ipykernel_23416\274231237.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_matches['y_is_wicket_fallen'][current_index] = 0
# C:\Users\Arul\AppData\Local\Temp\ipykernel_23416\274231237.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_matches['y_is_wicket_fallen'][current_index] = 1

# %%
df_matches
# Out:
#        Unnamed: 0            year  over_start_bowler_balls_bowled  \
# 0               0  ['2015-11-26']                               0
# 1               1  ['2015-11-26']                               0
# 2               2  ['2015-11-26']                               6
# 3               3  ['2015-11-26']                               7
# 4               4  ['2015-11-26']                              12
# ...           ...             ...                             ...
# 19105       19105  ['2018-04-03']                               6
# 19106       19106  ['2018-04-03']                              12
# 19107       19107  ['2018-04-03']                              12
# 19108       19108  ['2018-04-03']                              18
# 19109       19109  ['2018-04-03']                              12
#
#        over_start_bowler_wickets_taken  over_start_bowler_runs_given  \
# 0                                    0                             0
# ...

# %%
df_matches.to_csv('2022_to_2023_all_matches_preprocessed_v1.csv')

# %%
df_matches.columns
# Out:
# Index(['Unnamed: 0', 'year', 'over_start_bowler_balls_bowled',
#        'over_start_bowler_wickets_taken', 'over_start_bowler_runs_given',
#        'over_start_batsman_on_strike_fours',
#        'over_start_batsman_on_strike_sixers',
#        'over_start_batsman_off_strike_balls_faced',
#        'over_start_batsman_on_strike_balls_faced',
#        'over_start_batsman_offstrike_runs', 'over_start_batsman_onstrike_runs',
#        'innings', 'match_num', 'country', 'target', 'req_run_rate',
#        'over_start_run_rate', 'over_start_total_score',
#        'over_start_total_wickets_fallen', 'over', 'Bowler', 'batter_onStrike',
#        'batter_offstrike', 'wickets_fallen', 'sixers', 'fours', 'total_runs',
#        'bat_on_str_Ave', 'bat_on_str_SR', 'bat_on_str_100', 'bat_on_str_50',
#        'bat_on_str_0', 'bat_on_str_4s', 'bat_on_str_6s', 'bat_on_str_Mat',
#        'bat_on_str_Inns', 'bat_on_str_NO', 'bat_on_str_Runs', 'bat_on_str_HS',
# ...

# %% [markdown]
# ### Creating a Custom Data set for the RNN Inclusing next over bowler details

# %% [markdown]
# ##### Experiment Level

# %%
df_test = df_matches[0:100]

current_index = 0
run_rate = 0
while current_index < len(df_test):
if df_test['over'][current_index]<1:
    run_rate = 0
else:
    run_rate = df_test['over_start_total_score'][current_index] / (df['over'][current_index])
df['run_rate'][current_index] =  run_rate
    current_index = current_index + 1

df['target'] = pred_first_innings_score if df['innings'][current_index -1 ] == 1 else target
# Out:
# Unnamed: 0                                           0
# year                                    ['2015-11-26']
# over_start_bowler_balls_bowled                       0
# over_start_bowler_wickets_taken                      0
# over_start_bowler_runs_given                         0
#                                           ...
# bat_off_str_NO                                     5.0
# bat_off_str_Runs                                1092.0
# bat_off_str_HS                                   116.0
# bat_off_str_BF                                   797.0
# date                               2015-11-26 00:00:00
# Name: 0, Length: 66, dtype: object
# Unnamed: 0                                           1
# year                                    ['2015-11-26']
# over_start_bowler_balls_bowled                       0
# over_start_bowler_wickets_taken                      0
# over_start_bowler_runs_given                         0
#                                           ...
# ...

# %%
# Out:
# Unnamed: 0                                           0
# year                                    ['2015-11-26']
# over_start_bowler_balls_bowled                       0
# over_start_bowler_wickets_taken                      0
# over_start_bowler_runs_given                         0
#                                           ...
# bat_off_str_NO                                     5.0
# bat_off_str_Runs                                1092.0
# bat_off_str_HS                                   116.0
# bat_off_str_BF                                   797.0
# date                               2015-11-26 00:00:00
# Name: 0, Length: 66, dtype: object

# %%
col_list = ['bat_on_str_Ave', 'bat_on_str_SR', 'bat_on_str_100', 'bat_on_str_50',
       'bat_on_str_0', 'bat_on_str_4s', 'bat_on_str_6s', 'bat_on_str_Mat',
       'bat_on_str_Inns', 'bat_on_str_NO', 'bat_on_str_Runs', 'bat_on_str_HS',
       'bat_on_str_BF', 'bowler_Mat', 'bowler_Inns', 'bowler_Overs',
       'bowler_Mdns', 'bowler_Runs', 'bowler_Wkts', 'bowler_Ave',
       'bowler_Econ', 'bowler_SR', 'bowler_4w', 'bowler_5w', 'bat_off_str_Ave',
       'bat_off_str_SR', 'bat_off_str_100','bat_off_str_50', 'bat_off_str_0', 'bat_off_str_4s', 'bat_off_str_6s',
       'bat_off_str_Mat', 'bat_off_str_Inns', 'bat_off_str_NO',
       'bat_off_str_Runs', 'bat_off_str_HS', 'bat_off_str_BF',]

# %%
next_over_col = ['next_over_' + col_name for col_name in col_list]
print(next_over_col)
# Out:
# ['next_over_bat_on_str_Ave', 'next_over_bat_on_str_SR', 'next_over_bat_on_str_100', 'next_over_bat_on_str_50', 'next_over_bat_on_str_0', 'next_over_bat_on_str_4s', 'next_over_bat_on_str_6s', 'next_over_bat_on_str_Mat', 'next_over_bat_on_str_Inns', 'next_over_bat_on_str_NO', 'next_over_bat_on_str_Runs', 'next_over_bat_on_str_HS', 'next_over_bat_on_str_BF', 'next_over_bowler_Mat', 'next_over_bowler_Inns', 'next_over_bowler_Overs', 'next_over_bowler_Mdns', 'next_over_bowler_Runs', 'next_over_bowler_Wkts', 'next_over_bowler_Ave', 'next_over_bowler_Econ', 'next_over_bowler_SR', 'next_over_bowler_4w', 'next_over_bowler_5w', 'next_over_bat_off_str_Ave', 'next_over_bat_off_str_SR', 'next_over_bat_off_str_100', 'next_over_bat_off_str_50', 'next_over_bat_off_str_0', 'next_over_bat_off_str_4s', 'next_over_bat_off_str_6s', 'next_over_bat_off_str_Mat', 'next_over_bat_off_str_Inns', 'next_over_bat_off_str_NO', 'next_over_bat_off_str_Runs', 'next_over_bat_off_str_HS', 'next_over_bat_off_str_BF']

# %%
print(len(col_list))
print(len(next_over_col))
# Out:
# 37
# 37

# %%
df_test = df_test.assign(**dict(zip(next_over_col, [None]*len(next_over_col))))

# %%
df_test
# Out:
#     Unnamed: 0            year  over_start_bowler_balls_bowled  \
# 0            0  ['2015-11-26']                               0
# 1            1  ['2015-11-26']                               0
# 2            2  ['2015-11-26']                               6
# 3            3  ['2015-11-26']                               7
# 4            4  ['2015-11-26']                              12
# ..         ...             ...                             ...
# 95          95  ['2021-10-28']                              20
# 96          96  ['2021-10-28']                              19
# 97          97  ['2021-10-28']                              18
# 98          98  ['2021-10-28']                               0
# 99          99  ['2021-10-28']                               0
#
#     over_start_bowler_wickets_taken  over_start_bowler_runs_given  \
# 0                                 0                             0
# 1                                 0                             0
# ...

# %%
df_test[col_list].loc[1]
# Out:
# bat_on_str_Ave        14.00
# bat_on_str_SR        107.69
# bat_on_str_100         0.00
# bat_on_str_50          0.00
# bat_on_str_0           0.00
# bat_on_str_4s          3.00
# bat_on_str_6s          2.00
# bat_on_str_Mat         3.00
# bat_on_str_Inns        3.00
# bat_on_str_NO          0.00
# bat_on_str_Runs       42.00
# bat_on_str_HS         23.00
# bat_on_str_BF         39.00
# bowler_Mat            47.00
# bowler_Inns           47.00
# bowler_Overs         163.30
# bowler_Mdns            2.00
# bowler_Runs         1158.00
# bowler_Wkts           42.00
# bowler_Ave            27.57
# bowler_Econ            7.08
# bowler_SR             23.30
# bowler_4w              0.00
# bowler_5w              0.00
# bat_off_str_Ave       36.40
# bat_off_str_SR       137.01
# bat_off_str_100        1.00
# bat_off_str_50         7.00
# bat_off_str_0          3.00
# bat_off_str_4s       114.00
# bat_off_str_6s        35.00
# bat_off_str_Mat       35.00
# bat_off_str_Inns      35.00
# ...

# %%
df_test.loc[2, next_over_col] = pd.DataFrame(df_test.loc[2, col_list])

# %%
df_test
# Out:
#     Unnamed: 0            year  over_start_bowler_balls_bowled  \
# 0            0  ['2015-11-26']                               0
# 1            1  ['2015-11-26']                               0
# 2            2  ['2015-11-26']                               6
# 3            3  ['2015-11-26']                               7
# 4            4  ['2015-11-26']                              12
# ..         ...             ...                             ...
# 95          95  ['2021-10-28']                              20
# 96          96  ['2021-10-28']                              19
# 97          97  ['2021-10-28']                              18
# 98          98  ['2021-10-28']                               0
# 99          99  ['2021-10-28']                               0
#
#     over_start_bowler_wickets_taken  over_start_bowler_runs_given  \
# 0                                 0                             0
# 1                                 0                             0
# ...

# %%
df_test
# Out:
#     Unnamed: 0            year  over_start_bowler_balls_bowled  \
# 0            0  ['2015-11-26']                               0
# 1            1  ['2015-11-26']                               0
# 2            2  ['2015-11-26']                               6
# 3            3  ['2015-11-26']                               7
# 4            4  ['2015-11-26']                              12
# ..         ...             ...                             ...
# 95          95  ['2021-10-28']                              20
# 96          96  ['2021-10-28']                              19
# 97          97  ['2021-10-28']                              18
# 98          98  ['2021-10-28']                               0
# 99          99  ['2021-10-28']                               0
#
#     over_start_bowler_wickets_taken  over_start_bowler_runs_given  \
# 0                                 0                             0
# 1                                 0                             0
# ...

# %%
match_list = df_test['match_num'].unique()
match_list
# Out:
# array([ 468, 1361, 1374], dtype=int64)

# %%
next_over_col
# Out:
# ['next_over_bat_on_str_Ave',
#  'next_over_bat_on_str_SR',
#  'next_over_bat_on_str_100',
#  'next_over_bat_on_str_50',
#  'next_over_bat_on_str_0',
#  'next_over_bat_on_str_4s',
#  'next_over_bat_on_str_6s',
#  'next_over_bat_on_str_Mat',
#  'next_over_bat_on_str_Inns',
#  'next_over_bat_on_str_NO',
#  'next_over_bat_on_str_Runs',
#  'next_over_bat_on_str_HS',
#  'next_over_bat_on_str_BF',
#  'next_over_bowler_Mat',
#  'next_over_bowler_Inns',
#  'next_over_bowler_Overs',
#  'next_over_bowler_Mdns',
#  'next_over_bowler_Runs',
#  'next_over_bowler_Wkts',
#  'next_over_bowler_Ave',
#  'next_over_bowler_Econ',
#  'next_over_bowler_SR',
#  'next_over_bowler_4w',
#  'next_over_bowler_5w',
#  'next_over_bat_off_str_Ave',
#  'next_over_bat_off_str_SR',
#  'next_over_bat_off_str_100',
#  'next_over_bat_off_str_50',
#  'next_over_bat_off_str_0',
#  'next_over_bat_off_str_4s',
#  'next_over_bat_off_str_6s',
#  'next_over_bat_off_str_Mat',
#  'next_over_bat_off_str_Inns',
# ...

# %%
for match in match_list:
    print("In new Match" , match)
    for i in range(1,3):
        print("In new Innings" , i)
        innings_df = df_test[(df_test['match_num'] == match) & (df_test['innings'] == i)]
        print(len(innings_df))
        
        for over in range(0,len(innings_df)):
           if over == len(innings_df)-1 :
               print("last over")
               for k in range(0,len(col_list)):
                   df_test[next_over_col[k]][over] = df_test[col_list[k]][over]
           else:                   
               for k in range(0,len(col_list)):
                   df_test[next_over_col[k]][over] = df_test[col_list[k]][over+1]
# Out:
# C:\Users\Arul\AppData\Local\Temp\ipykernel_23416\923711090.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test[next_over_col[k]][over] = df_test[col_list[k]][over+1]
# In new Match 468
# In new Innings 1
# 20
# last over
# In new Innings 2
# 20
# last over
# In new Match 1361
# In new Innings 1
# 20
# C:\Users\Arul\AppData\Local\Temp\ipykernel_23416\923711090.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test[next_over_col[k]][over] = df_test[col_list[k]][over]
# last over
# In new Innings 2
# 18
# last over
# In new Match 1374
# In new Innings 1
# 20
# last over
# In new Innings 2
# 2
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_test[0:40]
# Out:
#     Unnamed: 0            year  over_start_bowler_balls_bowled  \
# 0            0  ['2015-11-26']                               0
# 1            1  ['2015-11-26']                               0
# 2            2  ['2015-11-26']                               6
# 3            3  ['2015-11-26']                               7
# 4            4  ['2015-11-26']                              12
# 5            5  ['2015-11-26']                               0
# 6            6  ['2015-11-26']                               0
# 7            7  ['2015-11-26']                               0
# 8            8  ['2015-11-26']                               6
# 9            9  ['2015-11-26']                               6
# 10          10  ['2015-11-26']                              12
# 11          11  ['2015-11-26']                               6
# 12          12  ['2015-11-26']                              18
# 13          13  ['2015-11-26']                              12
# ...
